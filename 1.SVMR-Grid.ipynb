# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'kernel':('linear', 'rbf','poly','sigmoid'), 'C':[1, 10,100,1000,2000,3000],'gamma':['auto','scale']}

grid=GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# C:\Users\Windows\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed:    7.9s finished
# C:\Users\Windows\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                            epsilon=0.1, gamma='auto_deprecated', kernel='rbf',
#                            max_iter=-1, shrinking=True, tol=0.001,
#                            verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'C': [1, 10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ('linear', 'rbf', 'poly', 'sigmoid')},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
re=grid.cv_results_


print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}: 0.8598930084494388

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.031249  0.000000e+00         0.015623    0.000000e+00       1
# 1        0.041657  7.367270e-03         0.015621    1.123916e-07       1
# 2        0.033413  3.076046e-03         0.005207    7.363897e-03       1
# 3        0.038631  1.043275e-02         0.015622    0.000000e+00       1
# 4        0.031240  2.472615e-06         0.005208    7.365471e-03       1
# 5        0.041655  7.362493e-03         0.015621    3.893359e-07       1
# 6        0.036450  7.364178e-03         0.010414    7.363897e-03       1
# 7        0.046864  2.247832e-07         0.015624    3.204639e-06       1
# 8        0.041657  7.363616e-03         0.000000    0.000000e+00      10
# 9        0.041653  7.360076e-03         0.015622    6.743496e-07      10
# 10       0.036449  7.364572e-03         0.005207    7.363897e-03      10
# 11       0.057021  7.188994e-03         0.015580    5.923037e-05      10
# 12       0.031242  3.104532e-06         0.005207    7.363897e-03      10
# 13       0.042167  8.022672e-03         0.022143    8.487424e-03      10
# 14       0.037865  1.034228e-02         0.001759    2.488238e-03      10
# 15       0.043088  5.341579e-03         0.015617    4.890003e-06      10
# 16       0.041654  7.360808e-03         0.005207    7.363560e-03     100
# 17       0.046864  7.867412e-07         0.010414    7.363673e-03     100
# 18       0.041671  7.373071e-03         0.000000    0.000000e+00     100
# 19       0.046850  1.709350e-05         0.015634    1.798266e-05     100
# 20       0.036462  7.382049e-03         0.005207    7.364122e-03     100
# 21       0.046851  1.742070e-05         0.010415    7.364235e-03     100
# 22       0.046863  1.434920e-06         0.005208    7.365583e-03     100
# 23       0.046864  1.030086e-06         0.015622    9.989584e-07     100
# 24       0.052070  7.364965e-03         0.010414    7.364010e-03    1000
# 25       0.062485  4.052337e-07         0.010414    7.364066e-03    1000
# 26       0.062485  6.836514e-07         0.010415    7.364853e-03    1000
# 27       0.057276  7.365078e-03         0.010415    7.364291e-03    1000
# 28       0.057277  7.363054e-03         0.000000    0.000000e+00    1000
# 29       0.057278  7.364122e-03         0.015622    1.123916e-07    1000
# 30       0.088521  3.681954e-02         0.010414    7.363897e-03    1000
# 31       0.052070  7.363897e-03         0.015621    2.973602e-07    1000
# 32       0.067693  7.363673e-03         0.010415    7.364178e-03    2000
# 33       0.072899  7.363746e-03         0.005209    7.366482e-03    2000
# 34       0.083314  1.948283e-02         0.010414    7.363897e-03    2000
# 35       0.052074  7.361426e-03         0.005203    7.357941e-03    2000
# 36       0.067685  7.355187e-03         0.000000    0.000000e+00    2000
# 37       0.072900  7.366033e-03         0.010414    7.364122e-03    2000
# 38       0.104175  1.943511e-02         0.010379    7.339359e-03    2000
# 39       0.046865  6.743496e-07         0.015621    1.083865e-06    2000
# 40       0.114556  2.945654e-02         0.005208    7.364572e-03    3000
# 41       0.078072  1.271311e-02         0.015656    5.046420e-05    3000
# 42       0.151006  3.209872e-02         0.015622    9.989584e-07    3000
# 43       0.046863  2.973602e-07         0.015622    4.899036e-07    3000
# 44       0.104142  2.655077e-02         0.005207    7.363111e-03    3000
# 45       0.074399  1.378877e-02         0.015623    9.602742e-07    3000
# 46       0.119763  1.948317e-02         0.006707    9.485289e-03    3000
# 47       0.037946  9.489449e-03         0.010415    7.364459e-03    3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto         poly
# 3         auto      sigmoid
# 4        scale       linear
# 5        scale          rbf
# 6        scale         poly
# 7        scale      sigmoid
# 8         auto       linear
# 9         auto          rbf
# 10        auto         poly
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale          rbf
# 14       scale         poly
# 15       scale      sigmoid
# 16        auto       linear
# 17        auto          rbf
# 18        auto         poly
# 19        auto      sigmoid
# 20       scale       linear
# 21       scale          rbf
# 22       scale         poly
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto         poly
# 27        auto      sigmoid
# 28       scale       linear
# 29       scale          rbf
# 30       scale         poly
# 31       scale      sigmoid
# 32        auto       linear
# 33        auto          rbf
# 34        auto         poly
# 35        auto      sigmoid
# 36       scale       linear
# 37       scale          rbf
# 38       scale         poly
# 39       scale      sigmoid
# 40        auto       linear
# 41        auto          rbf
# 42        auto         poly
# 43        auto      sigmoid
# 44       scale       linear
# 45       scale          rbf
# 46       scale         poly
# 47       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0       {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}           0.011498
# 1          {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}          -0.037926
# 2         {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}          -0.033024
# 3      {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.033054
# 4      {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}           0.011498
# 5         {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}          -0.037919
# 6        {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}          -0.033157
# 7     {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.033084
# 8      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.379453
# 9         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.001622
# 10       {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.045578
# 11    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.043747
# 12    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.379453
# 13       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.001551
# 14      {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.044344
# 15   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.043460
# 16    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.600824
# 17       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.280420
# 18      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.519516
# 19   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.497513
# 20   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.600824
# 21      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.280931
# 22     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.514963
# 23  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.495602
# 24   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.663978
# 25      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.713543
# 26     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.797601
# 27  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.405221
# 28  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.663978
# 29     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.713824
# 30    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.797154
# 31  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.385746
# 32   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.710113
# 33      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.794232
# 34     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.822616
# 35  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.192402
# 36  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.710113
# 37     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.794443
# 38    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.821856
# 39  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.038754
# 40   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.710020
# 41      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.805659
# 42     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.824951
# 43  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.935044
# 44  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.710020
# 45     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.805853
# 46    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.825027
# 47  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.924846
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           -0.082232          -0.073622        -0.048118        0.042302
# 1           -0.135679          -0.120518        -0.098041        0.042956
# 2           -0.129747          -0.115248        -0.092673        0.042592
# 3           -0.131053          -0.115582        -0.093230        0.043017
# 4           -0.082232          -0.073622        -0.048118        0.042302
# 5           -0.135688          -0.120519        -0.098042        0.042962
# 6           -0.129610          -0.115225        -0.092664        0.042486
# 7           -0.131022          -0.115577        -0.093228        0.042993
# 8            0.263743           0.270498         0.304565        0.053026
# 9           -0.097907          -0.088465        -0.062665        0.043335
# 10          -0.050102          -0.039371        -0.014632        0.042800
# 11          -0.054054          -0.044185        -0.018164        0.043962
# 12           0.263743           0.270498         0.304565        0.053026
# 13          -0.097995          -0.088478        -0.062675        0.043395
# 14          -0.048766          -0.039184        -0.014535        0.041817
# 15          -0.053762          -0.044135        -0.018146        0.043738
# 16           0.573673           0.559680         0.578059        0.017081
# 17           0.159180           0.155842         0.198481        0.057956
# 18           0.445794           0.421048         0.462119        0.041824
# 19           0.425077           0.420930         0.447840        0.035165
# 20           0.573673           0.559680         0.578059        0.017081
# 21           0.158637           0.155756         0.198441        0.058341
# 22           0.450772           0.421861         0.462532        0.038908
# 23           0.426898           0.421539         0.448013        0.033721
# 24           0.673763           0.637674         0.658471        0.015239
# 25           0.671971           0.640038         0.675184        0.030094
# 26           0.795391           0.764729         0.785907        0.015002
# 27           0.336416           0.349444         0.363694        0.029842
# 28           0.673763           0.637674         0.658471        0.015239
# 29           0.671576           0.639937         0.675112        0.030267
# 30           0.795738           0.764963         0.785952        0.014853
# 31           0.319360           0.346897         0.350668        0.027233
# 32           0.621857           0.634263         0.655411        0.039010
# 33           0.780655           0.746425         0.773770        0.020115
# 34           0.813670           0.779845         0.805377        0.018419
# 35          -0.162949          -0.041406        -0.132252        0.065354
# 36           0.621857           0.634263         0.655411        0.039010
# 37           0.780342           0.746377         0.773721        0.020174
# 38           0.813718           0.779857         0.805144        0.018187
# 39          -0.046722          -0.043343        -0.042940        0.003266
# 40           0.621851           0.632748         0.654873        0.039248
# 41           0.800880           0.768195         0.791578        0.016649
# 42           0.814057           0.783380         0.807463        0.017600
# 43          -0.652358          -0.912173        -0.833192        0.128209
# 44           0.621851           0.632748         0.654873        0.039248
# 45           0.800723           0.768175         0.791584        0.016684
# 46           0.813966           0.783395         0.807463        0.017607
# 47          -1.126127          -0.940265        -0.997079        0.091467
#
#     rank_test_score
# 0                36
# 1                44
# 2                41
# 3                43
# 4                36
# 5                45
# 6                40
# 7                42
# 8                27
# 9                38
# 10               32
# 11               34
# 12               27
# 13               39
# 14               31
# 15               33
# 16               19
# 17               29
# 18               22
# 19               24
# 20               19
# 21               30
# 22               21
# 23               23
# 24               13
# 25               11
# 26                8
# 27               25
# 28               13
# 29               12
# 30                7
# 31               26
# 32               15
# 33                9
# 34                3
# 35               46
# 36               15
# 37               10
# 38                4
# 39               35
# 40               17
# 41                6
# 42                1
# 43               47
# 44               17
# 45                5
# 46                2
# 47               48

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
childern_input=float(input("Childern:"))
sex_male_input=float(input("Sex Male 0 or 1 :"))
smoker_yes_input=float(input("Smoker Yes 0 or 1 :"))
# Out:
# Age:32
# BMI:24
# Childern:1
# Sex Male 0 or 1 :1
# Smoker Yes 0 or 1 :1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,childern_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[5412226.972399]
